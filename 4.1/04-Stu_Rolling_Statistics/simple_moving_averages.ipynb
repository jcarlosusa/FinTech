# %% [markdown]
# # Simple Moving Averages
#
# Harold has been asked to plot the 20-day, 50-day, and 100-day simple moving averages and rolling standard deviations for Netflix stock (NFLX). Upper management is looking to potentially invest long term in NFLX, but they want to be sure that they'll be taking a position at the right time.
#
# Use the Pandas library to help Harold plot the simple moving averages and rolling standard deviations in order to generate insights regarding whether or not the company should invest in NFLX long term.
#
# ## Instructions
#
#
# 1. Import libraries and dependencies.
#
# 2. Read in `nflx.csv` as a Pandas DataFrame, and set the Date column as a datetime index.
#
# 3. Use the `rolling` function and set the `window` parameter to designate the time windows. Then, use the `mean` function to calculate the following:
#
#     * 20-day simple moving average
#
#     * 50-day simple moving average
#
#     * 100-day simple moving average
#
# 4. Overlay the plot for daily closing prices of NFLX with the SMAs.
#
# 5. Use the `rolling` function and set the `window` parameter to designate the time windows. Then, use the `mean` function to calculate the following:
#
#     * 20-day rolling standard deviation
#
#     * 50-day rolling standard deviation
#
#     * 100-day rolling standard deviation
#
# 6. Overlay the plot for daily closing prices with the standard deviations.
#
# ## Hint
#
# Go [here](https://www.investopedia.com/terms/s/sma.asp) to learn more about simple moving averages and how they work.

# %%
# Import libraries and dependencies
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set file path
# Set file path
csv_path ='./nflx.csv'

# Read the CSV into a DataFrame and set the 'date' column as a datetime index
nflx_df = pd.read_csv(csv_path, index_col="date", infer_datetime_format=True, parse_dates=True)

# Read the CSV into a DataFrame and set the 'date' column as a datetime index
nflx_df = pd.read_csv("nflx.csv", index_col="date", infer_datetime_format=True, parse_dates=True)
nflx_df.sort_index(inplace=True)
nflx_df.head()

# Sort the data in forward chronological order, and display a few records
# Out:
#              close
# date
# 2009-05-18  5.5386
# 2009-05-19  5.6614
# 2009-05-20  5.7500
# 2009-05-21  5.5871
# 2009-05-22  5.5429

# %% [markdown]
# ### Plot Daily Closing Price of NFLX

# %%
# Plot DataFrame
nflx_df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Calculate 20-Day Simple Moving Average (SMA20)

# %%
# Calculate 20-day Simple Moving Average for NFLX Closing Prices
ntfl_sma_20 = nflx_df.rolling(window=20).mean().head(20)
ntfl_sma_20
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# 2009-05-26       NaN
# 2009-05-27       NaN
# 2009-05-28       NaN
# 2009-05-29       NaN
# 2009-06-01       NaN
# 2009-06-02       NaN
# 2009-06-03       NaN
# 2009-06-04       NaN
# 2009-06-05       NaN
# 2009-06-08       NaN
# 2009-06-09       NaN
# 2009-06-10       NaN
# 2009-06-11       NaN
# 2009-06-12       NaN
# 2009-06-15  5.610495

# %% [markdown]
# ### Calculate 50-Day Simple Moving Average (SMA50)

# %%
# Calculate 50-day Simple Moving Average for NFLX Closing Prices
nflx_df.rolling(window=50).mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Calculate 100-Day Simple Moving Average (SMA100)

# %%
# Calculate 100-day Simple Moving Average for NFLX Closing Prices
nflx_df.rolling(window=100).mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and SMAs

# %%
# Set figure of the daily closing prices of NFLX
ax = nflx_df.plot()

# Overlay SMA20, SMA50, and SMA100 on the same figure
nflx_df.rolling(window=20).mean().plot(ax=ax)
nflx_df.rolling(window=50).mean().plot(ax=ax)
nflx_df.rolling(window=100).mean().plot(ax=ax)

# Set the legend of the figure
ax.legend(["NTLX", "STD20", "STD50", "STD100"]);

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and STDs

# %%
# Set figure of the daily closing prices of NFLX


# Overlay STD20, STD50, and STD100 on the same figure


# Set the legend of the figure

# %% [markdown]
# ### Should Harold's firm invest long term in NFLX?
